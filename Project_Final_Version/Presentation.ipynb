# %%
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os 
os.chdir("/content/gdrive/My Drive/comp9517/project/Final_Work_ver1/Project_Framework")

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2020-08-03 12:45:15--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M  64.3MB/s    in 1.3s
#
# 2020-08-03 12:45:17 (64.3 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh.1’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda env remove -n demo

# %%
# !conda env create -f conda_env_demo.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ...
# keras-gpu-2.3.1      | 12 KB     | : 100% 1.0/1 [00:00<00:00,  9.86it/s]
# mkl_random-1.1.0     | 321 KB    | : 100% 1.0/1 [00:00<00:00,  6.97it/s]
# gmp-6.1.2            | 751 KB    | : 100% 1.0/1 [00:00<00:00,  3.54s/it]
# mkl-2020.1           | 129.0 MB  | : 100% 1.0/1 [00:04<00:00,  4.68s/it]
# ld_impl_linux-64-2.3 | 653 KB    | : 100% 1.0/1 [00:00<00:00,  4.91it/s]
# hdf5-1.10.2          | 4.8 MB    | : 100% 1.0/1 [00:01<00:00,  1.08s/it]
# ncurses-6.2          | 817 KB    | : 100% 1.0/1 [00:00<00:00,  3.67it/s]
# tqdm-4.46.0          | 60 KB     | : 100% 1.0/1 [00:00<00:00, 11.64it/s]
# pyasn1-modules-0.2.7 | 60 KB     | : 100% 1.0/1 [00:00<00:00, 14.43it/s]
# werkzeug-1.0.1       | 240 KB    | : 100% 1.0/1 [00:00<00:00, 10.25it/s]
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# pip install torch==0.4.1.post2
# pip install imagecodecs
# pip install libtiff
# conda install ipykernel
# conda deactivate
# Out:
# ...
#      |████████████████████████████████| 519.5 MB 20 kB/s
# ...
#      |████████████████████████████████| 17.9 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 129 kB 2.8 MB/s
# ...
#   Created wheel for libtiff: filename=libtiff-0.4.2-cp37-cp37m-linux_x86_64.whl size=316639 sha256=94a91cd386e7bc85940b694bbf6a3ab36df4b0a48756839fc2f3ae782d3bfae3
#   Stored in directory: /root/.cache/pip/wheels/ea/3d/1d/9ad926b88ecfd8719065c57ad36808810a77123c4647e8d341
# Successfully built libtiff
# ...
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/demo
#
#   added / updated specs:
#     - ipykernel
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
# ...

# %% [markdown]
# ## DIC-C2DH-HeLa DeepWater Seq 01

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# python3 main.py
# conda deactivate
# Out:
# Generating '/usr/local/envs/demo/lib/python3.7/site-packages/libtiff/tiff_h_4_1_0.py' from '/usr/local/envs/demo/lib/../include/tiff.h'
# Using TensorFlow backend.
# ./datasets/DIC-C2DH-HeLa/01
# the configuration file was loaded from ./deepwater_inference/checkpoints/DIC-C2DH-HeLa/config.yml
# DeepWater model was created!
# Start segmentation...
# 2020-08-03 12:52:00.885420: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-03 12:52:00.903105: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-03 12:52:00.904034: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# ...

# %% [markdown]
# ## DIC-C2DH-HeLa J-net Seq 02

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# python3 main.py
# conda deactivate

# %% [markdown]
# ## Fluo-N2DL-HeLa Thresholding Seq 03

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# python3 main.py
# conda deactivate

# %% [markdown]
# ## PhC-C2DL-PSC Thresholding Seq 04

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# python3 main.py
# conda deactivate
# Out:
# Using TensorFlow backend.
# ./datasets/PhC-C2DL-PSC/04
# Generating all frames and cell states...
# image number: 1 cell number: 74
# image number: 2 cell number: 74
# image number: 3 cell number: 75
# image number: 4 cell number: 75
# image number: 5 cell number: 72
# image number: 6 cell number: 74
# image number: 7 cell number: 74
# image number: 8 cell number: 76
# image number: 9 cell number: 75
# image number: 10 cell number: 74
# image number: 11 cell number: 75
# image number: 12 cell number: 77
# image number: 13 cell number: 76
# image number: 14 cell number: 78
# image number: 15 cell number: 82
# image number: 16 cell number: 82
# image number: 17 cell number: 78
# image number: 18 cell number: 80
# image number: 19 cell number: 79
# image number: 20 cell number: 84
# image number: 21 cell number: 81
# image number: 22 cell number: 82
# image number: 23 cell number: 82
# image number: 24 cell number: 79
# image number: 25 cell number: 79
# ...

# %% [markdown]
# ## PhC-C2DL-PSC DeepWater Seq 01

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate demo
# python3 main.py
# conda deactivate
# Out:
# Using TensorFlow backend.
# ./datasets/PhC-C2DL-PSC/01
# the configuration file was loaded from ./deepwater_inference/checkpoints/PhC-C2DL-PSC/config.yml
# DeepWater model was created!
# Start segmentation...
# 2020-08-02 05:11:29.789378: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-08-02 05:11:29.805373: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-02 05:11:29.806007: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla P100-PCIE-16GB computeCapability: 6.0
# coreClock: 1.3285GHz coreCount: 56 deviceMemorySize: 15.90GiB deviceMemoryBandwidth: 681.88GiB/s
# ...
