# %%
from google.colab import drive 
drive.mount("/content/gdrive")
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os 
os.chdir("/content/gdrive/My Drive/comp9517/project/Final_Work_ver1/Project_Framework")

# %%
################################################################################
# INSTALL CONDA ON GOOGLE COLAB
################################################################################
# ! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# # All requested packages already installed.
#
# installation finished.
# WARNING:
#     You currently have a PYTHONPATH environment variable set. This may cause
#     unexpected behavior when running the Python interpreter in Miniconda3.
#     For best results, please verify that your PYTHONPATH only points to
#     directories of packages that are compatible with the Python interpreter
#     in Miniconda3: /usr/local

# %%
# !conda env remove -n deepwater
# Out:
# Remove all packages in environment /usr/local/envs/deepwater:

# %%
# !conda env create -f ./deepwater_inference/conda_env_deepwater.yml
# Out:
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate deepwater
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %% [markdown]
# Install PyTorch 0.4.1.post2 and imagecodecs for JNet.

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate deepwater
# pip install torch==0.4.1.post2
# pip install imagecodecs
# pip install libtiff
# conda install ipykernel
# Out:
# ...
#   Using cached torch-0.4.1.post2-cp37-cp37m-manylinux1_x86_64.whl (519.5 MB)
# ...
#   Using cached imagecodecs-2020.5.30-cp37-cp37m-manylinux2014_x86_64.whl (17.9 MB)
# ...
# Processing /root/.cache/pip/wheels/ea/3d/1d/9ad926b88ecfd8719065c57ad36808810a77123c4647e8d341/libtiff-0.4.2-cp37-cp37m-linux_x86_64.whl
# ...
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.8.2
#   latest version: 4.8.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/deepwater
#
#   added / updated specs:
#     - ipykernel
#
#
# The following NEW packages will be INSTALLED:
#
#   backcall           pkgs/main/noarch::backcall-0.2.0-py_0
#   ipykernel          pkgs/main/linux-64::ipykernel-5.3.3-py37h5ca1d4c_0
#   ipython            pkgs/main/linux-64::ipython-7.16.1-py37h5ca1d4c_0
#   ipython_genutils   pkgs/main/linux-64::ipython_genutils-0.2.0-py37_0
# ...

# %%
# %%shell
# eval "$(conda shell.bash hook)" # copy conda command to shell
# conda activate deepwater
# python3 test.py
# conda deactivate
# Out:
# Using TensorFlow backend.
# the configuration file was loaded from ./deepwater_inference/checkpoints/DIC-C2DH-HeLa/config.yml
#
# In deepwater_object now, the config.MODEL_MARKER_PATH is: model_markers
#
#
# In deepwater_object now, the self.m_model_path is: ./deepwater_inference/checkpoints/DIC-C2DH-HeLa/model_markers.h5
#
#
# In deepwater_object now, the config.MODEL_FOREGROUND_PATH is: model_foreground
#
# DeepWater model was created!
# Start segmentation...
# 2020-07-24 13:57:24.100299: I tensorflow/stream_executor/platform/default/dso_loader.cc:44] Successfully opened dynamic library libcuda.so.1
# 2020-07-24 13:57:24.118517: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:981] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-07-24 13:57:24.119129: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1555] Found device 0 with properties:
# ...

# %%
import cv2 
img = cv2.imread("test_mask.tif",-1)
from matplotlib import pyplot as plt 
plt.imshow(img)

# %%
import cv2 
img = cv2.imread("m1.tif",-1)
from matplotlib import pyplot as plt 
plt.imshow(img)
